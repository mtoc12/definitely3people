# %%
import pandas as pd
import numpy as np
from zipfile import ZipFile

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from tqdm import tqdm
import copy

import seaborn as sns
import sklearn
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import xgboost as xgb

# %%
z = ZipFile("../caltech-cs155-2020.zip")

dfs = {text_file.filename: pd.read_csv(z.open(text_file.filename))
       for text_file in z.infolist()
       if text_file.filename.endswith('.csv')}
dfs.keys()
# Out:
# dict_keys(['sample_submission.csv', 'test.csv', 'train.csv'])

# %%
df_train = dfs['train.csv']
df_test = dfs['test.csv']
df_train.head()
# Out:
#    id  last_price     mid  opened_position_qty   closed_position_qty  \
# 0   0      3842.4  3842.6                   NaN                  NaN
# 1   1      3842.8  3843.4                   6.0                 49.0
# 2   2      3844.0  3844.3                   7.0                 77.0
# 3   3      3843.8  3843.4                   3.0                 34.0
# 4   4      3843.2  3843.1                   3.0                 38.0
#
#    transacted_qty  d_open_interest    bid1    bid2    bid3  ...  bid2vol  \
# 0           103.0                0  3842.4  3842.0  3841.8  ...        1
# 1            55.0              -43  3843.0  3842.8  3842.4  ...        6
# 2            84.0              -69  3843.8  3843.6  3843.2  ...        1
# 3            37.0              -30  3843.0  3842.8  3842.4  ...       13
# 4            41.0              -35  3842.8  3842.4  3842.0  ...       12
#
#    bid3vol  bid4vol  bid5vol  ask1vol  ask2vol  ask3vol  ask4vol  ask5vol  y
# 0        6       14        6        6        1        1       10        2  1
# 1       11        1        6        1        4        4        1       13  0
# 2        4       21       12        1       16       10        4        9  0
# 3       12        2        4        2        7        1        2       11  1
# 4        2        2        4        1        3        1       11       15  1
#
# [5 rows x 28 columns]

# %%
# Remove all rows with NaN to have it cleaner
array_train = df_train.to_numpy()
array_no_NaN = array_train[~np.isnan(array_train).any(axis = 1)]
array_no_NaN
# Out:
# array([[1.00000e+00, 3.84280e+03, 3.84340e+03, ..., 1.00000e+00,
#         1.30000e+01, 0.00000e+00],
#        [2.00000e+00, 3.84400e+03, 3.84430e+03, ..., 4.00000e+00,
#         9.00000e+00, 0.00000e+00],
#        [3.00000e+00, 3.84380e+03, 3.84340e+03, ..., 2.00000e+00,
#         1.10000e+01, 1.00000e+00],
#        ...,
#        [5.92374e+05, 4.10940e+03, 4.10980e+03, ..., 1.00000e+01,
#         7.00000e+00, 1.00000e+00],
#        [5.92375e+05, 4.11020e+03, 4.11030e+03, ..., 7.00000e+00,
#         7.00000e+00, 1.00000e+00],
#        [5.92376e+05, 4.10940e+03, 4.11050e+03, ..., 7.00000e+00,
#         5.00000e+00, 0.00000e+00]])

# %%
# Normalize feature vectors
norm_train = np.empty_like(array_train)

for i in range(28):
    col_max = max(array_no_NaN[:, i])
    col_min = 0
    norm_train[:, i] = (array_train[:, i] - col_min) / (col_max - col_min)

# %%
array_train = df_train.to_numpy()
# Make a copy of the column, so we don't change the original
vector_3 = copy.deepcopy(norm_train[:,3])
vector_4 = copy.deepcopy(norm_train[:,4])

# Train the first imputer
vector_3 = np.reshape(vector_3, (-1,1))
imp_v3 = IterativeImputer(max_iter=100, random_state=0)
imp_v3.fit(vector_3)
vector_3_trafo = imp_v3.transform(vector_3)
vector_3_trafo = vector_3_trafo.flatten()

# Train the second imputer
vector_4 = np.reshape(vector_4, (-1,1))
imp_v4 = IterativeImputer(max_iter=100, random_state=0)
imp_v4.fit(vector_4)
vector_4_trafo = imp_v4.transform(vector_4)
vector_4_trafo = vector_4_trafo.flatten()

# Put back into the normalized array
transform_train = copy.deepcopy(norm_train)
transform_train[:,3] = vector_3_trafo
transform_train[:,4] = vector_4_trafo

# %%
def trafo_to_df(array, df):
    key_list = list(df.keys())
    key_list.pop()
    df_dict = {}
    
    for i in range(27):
        temp = {key_list[i] : array[:,i]}
        df_dict.update(temp)
        
    new_df = pd.DataFrame(data = df_dict)
    
    return new_df

# %%
df_train = trafo_to_df(transform_train[:,:-1], df_train)
df_test_dict = {'y' : transform_train[:,-1]}
df_train_y = pd.DataFrame(data = df_test_dict)
df_train.head()
# Out:
#          id  last_price       mid  opened_position_qty   closed_position_qty  \
# 0  0.000000    0.933573  0.933576              0.017507             0.009265
# 1  0.000002    0.933670  0.933771              0.075000             0.231132
# 2  0.000003    0.933962  0.933989              0.087500             0.363208
# 3  0.000005    0.933913  0.933771              0.037500             0.160377
# 4  0.000007    0.933767  0.933698              0.037500             0.179245
#
#    transacted_qty  d_open_interest      bid1      bid2      bid3  ...  \
# 0        0.407115             0.00  0.933573  0.933521  0.933609  ...
# 1        0.217391            -0.86  0.933719  0.933716  0.933755  ...
# 2        0.332016            -1.38  0.933913  0.933910  0.933949  ...
# 3        0.146245            -0.60  0.933719  0.933716  0.933755  ...
# 4        0.162055            -0.70  0.933670  0.933618  0.933657  ...
#
#     bid1vol   bid2vol   bid3vol   bid4vol   bid5vol   ask1vol   ask2vol  \
# 0  0.072727  0.007194  0.044118  0.117647  0.050000  0.046154  0.007576
# 1  0.063636  0.043165  0.080882  0.008403  0.050000  0.007692  0.030303
# 2  0.027273  0.007194  0.029412  0.176471  0.100000  0.007692  0.121212
# 3  0.090909  0.093525  0.088235  0.016807  0.033333  0.015385  0.053030
# 4  0.127273  0.086331  0.014706  0.016807  0.033333  0.007692  0.022727
#
#     ask3vol   ask4vol   ask5vol
# 0  0.007519  0.074627  0.014815
# 1  0.030075  0.007463  0.096296
# 2  0.075188  0.029851  0.066667
# 3  0.007519  0.014925  0.081481
# 4  0.007519  0.082090  0.111111
#
# [5 rows x 27 columns]

# %%
#splitting into training and validation sets 
X_train, X_validate, y_train, y_validate = train_test_split(df_train, df_train_y, test_size=0.3, shuffle = False)

# %%
xgb3 = xgb.XGBClassifier(
    learning_rate =0.1,
    n_estimators=1000,
    max_depth=2,
    min_child_weight=1,
    gamma=0.0,
    subsample=0.6,
    colsample_bytree=0.8,
    objective= 'binary:logistic',
    seed=28
)

eval_set = [(X_train, y_train), (X_validate, y_validate)]

# %%
xgb3.fit(X_train, y_train, eval_metric ='auc',eval_set=eval_set, early_stopping_rounds=10)
# Out:
# C:\Users\Bioware\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Bioware\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-auc:0.609272	validation_1-auc:0.600676
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.621907	validation_1-auc:0.612379
# [2]	validation_0-auc:0.625179	validation_1-auc:0.61549
# [3]	validation_0-auc:0.629316	validation_1-auc:0.619372
# [4]	validation_0-auc:0.63185	validation_1-auc:0.622059
# [5]	validation_0-auc:0.632793	validation_1-auc:0.6232
# [6]	validation_0-auc:0.634091	validation_1-auc:0.624233
# [7]	validation_0-auc:0.634067	validation_1-auc:0.623894
# [8]	validation_0-auc:0.634121	validation_1-auc:0.624131
# [9]	validation_0-auc:0.634283	validation_1-auc:0.624161
# [10]	validation_0-auc:0.634837	validation_1-auc:0.62474
# [11]	validation_0-auc:0.63519	validation_1-auc:0.625092
# [12]	validation_0-auc:0.635547	validation_1-auc:0.625457
# [13]	validation_0-auc:0.636354	validation_1-auc:0.626143
# [14]	validation_0-auc:0.636908	validation_1-auc:0.626692
# [15]	validation_0-auc:0.637599	validation_1-auc:0.627229
# [16]	validation_0-auc:0.637628	validation_1-auc:0.627189
# [17]	validation_0-auc:0.6379	validation_1-auc:0.627507
# [18]	validation_0-auc:0.638512	validation_1-auc:0.628051
# [19]	validation_0-auc:0.639119	validation_1-auc:0.628752
# [20]	validation_0-auc:0.639349	validation_1-auc:0.628986
# [21]	validation_0-auc:0.639477	validation_1-auc:0.629113
# [22]	validation_0-auc:0.639699	validation_1-auc:0.629426
# [23]	validation_0-auc:0.640048	validation_1-auc:0.629822
# [24]	validation_0-auc:0.640184	validation_1-auc:0.629926
# [25]	validation_0-auc:0.640355	validation_1-auc:0.629966
# [26]	validation_0-auc:0.640462	validation_1-auc:0.630127
# [27]	validation_0-auc:0.640491	validation_1-auc:0.630175
# [28]	validation_0-auc:0.640746	validation_1-auc:0.63047
# [29]	validation_0-auc:0.640906	validation_1-auc:0.630644
# [30]	validation_0-auc:0.641001	validation_1-auc:0.630683
# [31]	validation_0-auc:0.641151	validation_1-auc:0.630785
# [32]	validation_0-auc:0.641311	validation_1-auc:0.630926
# [33]	validation_0-auc:0.641579	validation_1-auc:0.631232
# [34]	validation_0-auc:0.641669	validation_1-auc:0.631348
# [35]	validation_0-auc:0.641741	validation_1-auc:0.631412
# [36]	validation_0-auc:0.641932	validation_1-auc:0.631667
# [37]	validation_0-auc:0.642035	validation_1-auc:0.631824
# [38]	validation_0-auc:0.6421	validation_1-auc:0.631884
# [39]	validation_0-auc:0.642276	validation_1-auc:0.632164
# [40]	validation_0-auc:0.642307	validation_1-auc:0.632152
# [41]	validation_0-auc:0.642379	validation_1-auc:0.632221
# [42]	validation_0-auc:0.642438	validation_1-auc:0.632309
# [43]	validation_0-auc:0.642482	validation_1-auc:0.632389
# [44]	validation_0-auc:0.642619	validation_1-auc:0.632575
# [45]	validation_0-auc:0.642724	validation_1-auc:0.632692
# [46]	validation_0-auc:0.642879	validation_1-auc:0.632798
# [47]	validation_0-auc:0.642975	validation_1-auc:0.632921
# [48]	validation_0-auc:0.643038	validation_1-auc:0.63299
# [49]	validation_0-auc:0.643114	validation_1-auc:0.6331
# [50]	validation_0-auc:0.643174	validation_1-auc:0.633158
# [51]	validation_0-auc:0.643235	validation_1-auc:0.633174
# [52]	validation_0-auc:0.643292	validation_1-auc:0.633257
# [53]	validation_0-auc:0.643386	validation_1-auc:0.633391
# [54]	validation_0-auc:0.64343	validation_1-auc:0.633435
# [55]	validation_0-auc:0.643467	validation_1-auc:0.63347
# [56]	validation_0-auc:0.643501	validation_1-auc:0.633507
# [57]	validation_0-auc:0.643573	validation_1-auc:0.633606
# [58]	validation_0-auc:0.64366	validation_1-auc:0.633775
# [59]	validation_0-auc:0.643708	validation_1-auc:0.633822
# [60]	validation_0-auc:0.643844	validation_1-auc:0.633822
# [61]	validation_0-auc:0.643909	validation_1-auc:0.63384
# [62]	validation_0-auc:0.64396	validation_1-auc:0.633883
# [63]	validation_0-auc:0.643998	validation_1-auc:0.633945
# [64]	validation_0-auc:0.644026	validation_1-auc:0.63398
# [65]	validation_0-auc:0.644093	validation_1-auc:0.633971
# [66]	validation_0-auc:0.644204	validation_1-auc:0.633971
# [67]	validation_0-auc:0.64425	validation_1-auc:0.633975
# [68]	validation_0-auc:0.644276	validation_1-auc:0.63401
# [69]	validation_0-auc:0.644326	validation_1-auc:0.63409
# [70]	validation_0-auc:0.64436	validation_1-auc:0.63412
# [71]	validation_0-auc:0.644419	validation_1-auc:0.63416
# [72]	validation_0-auc:0.644466	validation_1-auc:0.634205
# [73]	validation_0-auc:0.6445	validation_1-auc:0.634184
# [74]	validation_0-auc:0.644545	validation_1-auc:0.634244
# [75]	validation_0-auc:0.644563	validation_1-auc:0.634271
# [76]	validation_0-auc:0.64462	validation_1-auc:0.634287
# [77]	validation_0-auc:0.644666	validation_1-auc:0.634344
# [78]	validation_0-auc:0.64472	validation_1-auc:0.634373
# [79]	validation_0-auc:0.64474	validation_1-auc:0.634385
# [80]	validation_0-auc:0.644777	validation_1-auc:0.634385
# [81]	validation_0-auc:0.644808	validation_1-auc:0.634459
# [82]	validation_0-auc:0.644842	validation_1-auc:0.634481
# [83]	validation_0-auc:0.644872	validation_1-auc:0.63453
# [84]	validation_0-auc:0.644885	validation_1-auc:0.634543
# [85]	validation_0-auc:0.644918	validation_1-auc:0.63453
# [86]	validation_0-auc:0.644953	validation_1-auc:0.63456
# [87]	validation_0-auc:0.64496	validation_1-auc:0.634549
# [88]	validation_0-auc:0.644989	validation_1-auc:0.634576
# [89]	validation_0-auc:0.645022	validation_1-auc:0.634575
# [90]	validation_0-auc:0.645043	validation_1-auc:0.634569
# [91]	validation_0-auc:0.645071	validation_1-auc:0.634572
# [92]	validation_0-auc:0.645109	validation_1-auc:0.634577
# [93]	validation_0-auc:0.645147	validation_1-auc:0.634576
# [94]	validation_0-auc:0.645176	validation_1-auc:0.634617
# [95]	validation_0-auc:0.645184	validation_1-auc:0.634624
# [96]	validation_0-auc:0.645305	validation_1-auc:0.634624
# [97]	validation_0-auc:0.645319	validation_1-auc:0.634645
# [98]	validation_0-auc:0.645378	validation_1-auc:0.634645
# [99]	validation_0-auc:0.645405	validation_1-auc:0.634606
# [100]	validation_0-auc:0.645433	validation_1-auc:0.634637
# [101]	validation_0-auc:0.645452	validation_1-auc:0.634638
# [102]	validation_0-auc:0.645481	validation_1-auc:0.634638
# [103]	validation_0-auc:0.64551	validation_1-auc:0.634623
# [104]	validation_0-auc:0.645541	validation_1-auc:0.634721
# [105]	validation_0-auc:0.645574	validation_1-auc:0.634726
# [106]	validation_0-auc:0.645593	validation_1-auc:0.634595
# [107]	validation_0-auc:0.645611	validation_1-auc:0.6346
# [108]	validation_0-auc:0.64571	validation_1-auc:0.6346
# [109]	validation_0-auc:0.645749	validation_1-auc:0.634607
# [110]	validation_0-auc:0.645767	validation_1-auc:0.634609
# [111]	validation_0-auc:0.645783	validation_1-auc:0.634633
# [112]	validation_0-auc:0.645809	validation_1-auc:0.634632
# [113]	validation_0-auc:0.64583	validation_1-auc:0.63409
# [114]	validation_0-auc:0.645859	validation_1-auc:0.634127
# [115]	validation_0-auc:0.645882	validation_1-auc:0.634127
# Stopping. Best iteration:
# [105]	validation_0-auc:0.645574	validation_1-auc:0.634726
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0.0,
#               learning_rate=0.1, max_delta_step=0, max_depth=2,
#               min_child_weight=1, missing=None, n_estimators=1000, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=28,
#               silent=None, subsample=0.6, verbosity=1)

# %%
#predict on validation set
ypred_xgb3 = xgb3.predict_proba(X_validate)[:,1]

# %%
#calculate AUC on validation set
roc = sklearn.metrics.roc_auc_score(y_validate, ypred_xgb3)
print("AUC: %.4f%% " % (roc * 100))
# Out:
# AUC: 63.4726%

# %%
#predict on test set
predictions = xgb3.predict_proba(df_test)

# Kaggle needs the submission to have a certain format;
submission = pd.DataFrame({ 'id': df_test.index,
                            'Predicted': predictions[:,1]})

# %%
#is the format correct?
submission.head()
# Out:
#    id  Predicted
# 0   0   0.505949
# 1   1   0.415898
# 2   2   0.415898
# 3   3   0.508599
# 4   4   0.287998

# %%
submission.to_csv("submission_vector.csv", index=False)
